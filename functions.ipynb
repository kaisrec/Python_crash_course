# %%
def describ_pet(animal_type, pet_name):
    """Display information about a pet."""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describ_pet('hamster', 'harry')
describ_pet('dog', 'willie')
# Out:
# I have a hamster.
# My hamster's name is Harry.
#
# I have a dog.
# My dog's name is Willie.

# %%
def get_formatted_name(first_name, last_name):
    """Return a full name, neatly formatted."""
    full_name = f"{first_name} {last_name}"
    return full_name.title()
    print (full_name)
musician = get_formatted_name('jimi', 'hendrix')
musician
# Out:
# 'Jimi Hendrix'

# %% [markdown]
# Making an Argument Optional

# %%
def get_formatted_name(first_name, last_name, middle_name=''):
    """Return a full name, neatly formatted."""
    if middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
    return full_name.title()
get_formatted_name('jimi', 'hendrix', 'lee')
# Out:
# 'Jimi Hendrix'

# %% [markdown]
# Returning a Dictionary

# %%
def build_person(first_name, last_name):
    """Return a dictionary of information about a person."""
    person = {'first': first_name, 'last': last_name}
    return person
musician = build_person('kais', 'rec')
musician
# Out:
# {'first': 'kais', 'last': 'rec'}

# %%
def build_person(first_name, last_name, age=None):
    """Return a dictionary of information about a person."""
    person = {'first': first_name, 'last': last_name}
    if age:
        person['age'] = age
    return person
musician = build_person('kais', 'rec')
musician
# Out:
# {'first': 'kais', 'last': 'rec'}

# %%
def build_person(first_name, last_name="", age=""):
    if last_name:
        person["lastname"]= last_name
    if age:     
        person["age"]= age
    person = {'first': first_name, 'last': last_name, 'age': age}
    return person
musician = build_person('kais')
musician
# Out:
# {'first': 'kais', 'last': '', 'age': ''}

# %% [markdown]
# Passing a list

# %%
def greet_user(username):
    """Display a simple greeting."""
    for name in username:
        msg = f"Hello, {name.title()}!"
        print(msg)
usernames = ['hannah', 'ty', 'margot']
greet_user(usernames)
# Out:
# Hello, Hannah!
# Hello, Ty!
# Hello, Margot!

# %% [markdown]
# Modifying a list in a function

# %%
def count_up_to(n):
    for i in range(n):
        yield i  # Pauses here, yields i

gen = count_up_to(10)

# %%
print(next(gen))  # Outputs 0
# Out:
# 3

# %%
def make_pizza(size, *top):
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
    for topping in top:
        print(f"- {topping}")
make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 12-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %% [markdown]
# Using Arbitrary Keyword Arguments

# %%
def build_person(first, last,**user_info):

    user_info['first_name'] = first
    user_info['last_name'] = last   
    return user_info
user_profile = build_person('kais', 'rec', location='berlin', field='engineering', country='germany')
user_profile
# Out:
# {'location': 'berlin',
#  'field': 'engineering',
#  'country': 'germany',
#  'first_name': 'kais',
#  'last_name': 'rec'}
