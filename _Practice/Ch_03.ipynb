# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
cars = ['bmw', 'audi', 'toyota', 'subaru']
hello = "Hello, World!"

# %%
i = 0
for bicycle in bicycles:
    i=i+1
    print(f"* {i} item: {bicycle.title()}")
# Out:
# * 1 item: Trek
# * 2 item: Cannondale
# * 3 item: Redline
# * 4 item: Specialized

# %%
bicycles
y = enumerate(bicycles)
print(list(y))
# Out:
# [(0, 'trek'), (1, 'cannondale'), (2, 'redline'), (3, 'specialized')]

# %%
for i, bicycle in enumerate(bicycles, start=1):
    print(f"* {i} item: {bicycle.title()}")
# Out:
# * 1 item: Trek
# * 2 item: Cannondale
# * 3 item: Redline
# * 4 item: Specialized

# %%
# List comprehension with manual index
result = [f"{i}: {v}" for i, v in enumerate(bicycles, start=1)]
# Iterate over the result and print each formatted string
for item in result:
    print(item)
# Out:
# 1: trek
# 2: cannondale
# 3: redline
# 4: specialized

# %%
a = enumerate(bicycles)
a
