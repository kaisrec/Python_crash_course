# %% [markdown]
# ## Dictionary

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_0['x-position'] = 0
alien_0['y-position'] = 0
a = list(range(0, 10))
for i in a:
    alien_0['x-position'] += 1
    alien_0['y-position'] += 2
    print(f"New x-position: {alien_0}")
# Out:
# New x-position: {'color': 'green', 'points': 5, 'x-position': 1, 'y-position': 2}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 2, 'y-position': 4}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 3, 'y-position': 6}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 4, 'y-position': 8}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 5, 'y-position': 10}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 6, 'y-position': 12}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 7, 'y-position': 14}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 8, 'y-position': 16}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 9, 'y-position': 18}
# New x-position: {'color': 'green', 'points': 5, 'x-position': 10, 'y-position': 20}
